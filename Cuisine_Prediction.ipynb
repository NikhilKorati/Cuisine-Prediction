# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import io
from io import StringIO

# %%
# !wget https://www.dropbox.com/s/v3hvge1q9rnnuzl/recipes.csv
    
df = pd.read_csv('recipes.csv')
# Out:
# --2017-10-31 16:19:32--  https://www.dropbox.com/s/v3hvge1q9rnnuzl/recipes.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.1, 2620:100:601b:1::a27d:801
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl.dropboxusercontent.com/content_link/mANdUOM4Ul985N8gq0Xo7rQyVuK3JZYTWXVUJPzciPDyi6IexIdAXjS0TEC9V8mF/file [following]
# --2017-10-31 16:19:33--  https://dl.dropboxusercontent.com/content_link/mANdUOM4Ul985N8gq0Xo7rQyVuK3JZYTWXVUJPzciPDyi6IexIdAXjS0TEC9V8mF/file
# Resolving dl.dropboxusercontent.com (dl.dropboxusercontent.com)... 162.125.8.6, 2620:100:601b:6::a27d:806
# Connecting to dl.dropboxusercontent.com (dl.dropboxusercontent.com)|162.125.8.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67284474 (64M) [text/csv]
# Saving to: ‘recipes.csv.2’
#
# recipes.csv.2       100%[===================>]  64.17M  4.97MB/s    in 14s
#
# 2017-10-31 16:19:47 (4.72 MB/s) - ‘recipes.csv.2’ saved [67284474/67284474]

# %%
df.head(5)
# Out:
#       country almond angelica anise anise_seed apple apple_brandy apricot  \
# 0  Vietnamese     No       No    No         No    No           No      No
# 1  Vietnamese     No       No    No         No    No           No      No
# 2  Vietnamese     No       No    No         No    No           No      No
# 3  Vietnamese     No       No    No         No    No           No      No
# 4  Vietnamese     No       No    No         No    No           No      No
#
#   armagnac artemisia   ...    whiskey white_bread white_wine  \
# 0       No        No   ...         No          No         No
# 1       No        No   ...         No          No         No
# 2       No        No   ...         No          No         No
# 3       No        No   ...         No          No         No
# 4       No        No   ...         No          No         No
#
#   whole_grain_wheat_flour wine wood yam yeast yogurt zucchini
# 0                      No   No   No  No    No     No       No
# 1                      No   No   No  No    No     No       No
# 2                      No   No   No  No    No     No       No
# 3                      No   No   No  No    No     No       No
# 4                      No   No   No  No    No     No       No
#
# [5 rows x 384 columns]
